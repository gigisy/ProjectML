# %% [markdown]
# <a href="https://colab.research.google.com/github/gigisy/ProjectML/blob/main/SurvivalAnalysis/4_korelasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data1= {'X': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
       'Y': [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.78]}
data2={'X': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
       'Y': [9.14, 8.14, 8.74, 8.77, 9.26, 8.1, 6.13, 3.1, 9.13, 7.26, 4.74]}
data3={'X': [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5],
       'Y': [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 9.13, 7.26, 4.74]}
data4= {'X': [8, 8, 8, 8, 8, 8, 18, 19, 8, 8, 8],
       'Y': [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.5, 5.56, 7.91, 6.89]}
df1 =pd.DataFrame(data1)
df2 =pd.DataFrame(data2)
df3 =pd.DataFrame(data3)
df4 =pd.DataFrame(data4)

# %%
df1.corr()
# Out:
#           X         Y
# X  1.000000  0.813993
# Y  0.813993  1.000000

# %%
df2.corr()
# Out:
#           X         Y
# X  1.000000  0.816237
# Y  0.816237  1.000000

# %%
df3.corr()
# Out:
#           X         Y
# X  1.000000  0.839124
# Y  0.839124  1.000000

# %%
df4.corr()
# Out:
#           X         Y
# X  1.000000  0.376078
# Y  0.376078  1.000000

# %%
# Plotting the data as a scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(df1['X'], df1['Y'],
            color='purple', label='Data Points')
plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting the data as a scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(df2['X'], df2['Y'], color='purple', label='Data Points')
plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting the data as a scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(df3['X'], df3['Y'], color='purple', label='Data Points')
plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting the data as a scatter plot
plt.figure(figsize=(6, 4))
plt.scatter(df4['X'], df4['Y'], color='b', label='Data Points')
plt.title('Scatter Plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.legend()
plt.show()
